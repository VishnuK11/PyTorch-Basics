# %%
import torch
import numpy as np

# %% [markdown]
# #Tensors

# %%
t1 = torch.tensor(4.)

# %%
t1.dtype
# Out:
# torch.int64

# %%
# 1 D array
t2 = torch.tensor([5.,6,7]) # Converts everything to one dtype

# %%
# 2 D Array
t3 = torch.tensor([[ 5., 6],[6,7],[8,9]])

# %%
t3
# Out:
# tensor([[5., 6.],
#         [6., 7.],
#         [8., 9.]])

# %%
t3.shape
# Out:
# torch.Size([3, 2])

# %% [markdown]
# #Tensor Operations and Gradients

# %%
x = torch.tensor(1.)
w = torch.tensor(3., requires_grad=True)
b = torch.tensor(4., requires_grad=True)
y = w * x + b

# %%
y.backward()

# %%
w.grad
# Out:
# tensor(1.)
